# %% [markdown]
# # 1. Подготовка данных и обучение нейронных сетей

# %%
from keras.layers import SimpleRNN, LSTM, SimpleRNNCell
from keras.models import Sequential

import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, Flatten, Dropout
from tensorflow.keras.layers import GRU
from tensorflow.keras.models import Model

from sklearn.preprocessing import MinMaxScaler

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

pd.options.display.float_format = "{:.2f}".format

plt.style.use("ggplot")
plt.rcParams["figure.figsize"] = (15, 15)

# %%
data = pd.read_csv('https://drive.usercontent.google.com/u/0/uc?id=1xwXieDVy1RKdfiJ6am_nNWp6XhAYdhNb&export=download')

# %%
data.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %% [markdown]
# Столбец `Month` сделаем индексом. Будем обучать модель, используя только один признак - `Passengers`.

# %%
data['Month'] = pd.to_datetime(data['Month'])

data.set_index('Month', inplace=True)
data.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# Сразу применим масштабирование к временному ряду.

# %%
scaler = MinMaxScaler()

data['Passengers'] = scaler.fit_transform(data['Passengers'].values.reshape(-1,1))

# %% [markdown]
# Далее подготовим данные для модели с одномерным входом по аналогии со скринкастом Web5. На вход в модель будут подаваться последние 12 значений пассажиров, и модель необходимо обучить прогнозировать число пассажиров на следующем шаге по времени.

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i - history_size, i)
        data.append(np.reshape(dataset[indices], (history_size, 1)))
        labels.append(dataset[i + target_size])
    return np.array(data), np.array(labels)

# %%
past_history = 12
future_target = 0

train_size = 108

X_train, y_train = univariate_data(data.values, 0, train_size,
                                           past_history,
                                           future_target)

X_val, y_val = univariate_data(data.values, train_size, None,
                                       past_history,
                                       future_target)

# %%
X_train[0], y_train[0]
# Out:
# (array([[0.01544402],
#         [0.02702703],
#         [0.05405405],
#         [0.04826255],
#         [0.03281853],
#         [0.05984556],
#         [0.08494208],
#         [0.08494208],
#         [0.06177606],
#         [0.02895753],
#         [0.        ],
#         [0.02702703]]),
#  array([0.02123552]))

# %%
X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((96, 12, 1), (96, 1), (24, 12, 1), (24, 1))

# %% [markdown]
# С помощью tf.data выполним перемешивание shuffle, пакетирование batch и кэширование cache набора данных.

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))

# Перемешиваем и пакетируем данные для обучения
batch_size = 8
buffer_size = 1000

train_dataset = train_dataset.shuffle(buffer_size).batch(batch_size).cache()
val_dataset = val_dataset.batch(batch_size).cache()

# %%
for input, _ in train_dataset:
    print(input.shape)
    break
# Out:
# (8, 12, 1)

# %%
def plot_predictions(train_true, train_pred, test_true, test_pred):
    plt.figure(figsize=(10, 6))

    # График для тренировочных данных
    plt.plot(train_true, label='Train True', color='blue')
    plt.plot(train_pred, label='Train Predictions', color='green', linestyle='--')

    # График для тестовых данных
    plt.plot(range(len(train_true), len(train_true) + len(test_true)),
             test_true, label='Test True', color='red')
    plt.plot(range(len(train_true), len(train_true) + len(test_true)),
             test_pred, label='Test Predictions', color='orange', linestyle='--')

    plt.title('True vs Predicted')
    plt.xlabel('Sample')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# %% [markdown]
# ## 1. Обучение Simple RNN

# %% [markdown]
# Для начала обучим нейронную сеть Simple RNN.

# %%
from keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='loss', patience=20)

model_rnn = Sequential([
    SimpleRNN(64,
              input_shape=(input.shape[1], input.shape[2])),
    Dense(1)
])

model_rnn.summary()
# Out:
# Model: "sequential_49"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_44 (SimpleRNN)   (None, 64)                4224
#
#  dense_49 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 4289 (16.75 KB)
# Trainable params: 4289 (16.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_rnn.compile(optimizer='adam', loss='mse')

history_rnn = model_rnn.fit(train_dataset,
                            epochs=100,
                            batch_size=batch_size,
                            verbose=1,
                            validation_data=val_dataset,
                            callbacks=[early_stop])

# Визуализация процесса обучения
plt.plot(history_rnn.history['loss'], label='Simple RNN Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 12/12 [==============================] - 2s 35ms/step - loss: 0.0245 - val_loss: 0.0777
# Epoch 2/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0351
# Epoch 3/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0181
# Epoch 4/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0269
# Epoch 5/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0283
# Epoch 6/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0240
# Epoch 7/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0208
# Epoch 8/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0190
# Epoch 9/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0177
# Epoch 10/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0166
# Epoch 11/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0152
# Epoch 12/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0139
# Epoch 13/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0127
# Epoch 14/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0116
# Epoch 15/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0107
# Epoch 16/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0099
# Epoch 17/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0092
# Epoch 18/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0086
# Epoch 19/100
# 12/12 [==============================] - 0s 5ms/step - loss: 9.9655e-04 - val_loss: 0.0081
# Epoch 20/100
# 12/12 [==============================] - 0s 4ms/step - loss: 9.7335e-04 - val_loss: 0.0077
# Epoch 21/100
# 12/12 [==============================] - 0s 4ms/step - loss: 9.5139e-04 - val_loss: 0.0073
# Epoch 22/100
# 12/12 [==============================] - 0s 4ms/step - loss: 9.3070e-04 - val_loss: 0.0069
# Epoch 23/100
# 12/12 [==============================] - 0s 4ms/step - loss: 9.1131e-04 - val_loss: 0.0065
# Epoch 24/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.9318e-04 - val_loss: 0.0062
# Epoch 25/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.7628e-04 - val_loss: 0.0059
# Epoch 26/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.6086e-04 - val_loss: 0.0014
# Epoch 83/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.5913e-04 - val_loss: 0.0014
# Epoch 84/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.5745e-04 - val_loss: 0.0014
# Epoch 85/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.5583e-04 - val_loss: 0.0014
# Epoch 86/100
# 12/12 [==============================] - 0s 5ms/step - loss: 5.5426e-04 - val_loss: 0.0013
# Epoch 87/100
# 12/12 [==============================] - 0s 5ms/step - loss: 5.5274e-04 - val_loss: 0.0013
# Epoch 88/100
# 12/12 [==============================] - 0s 5ms/step - loss: 5.5128e-04 - val_loss: 0.0013
# Epoch 89/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.4986e-04 - val_loss: 0.0013
# Epoch 90/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.4849e-04 - val_loss: 0.0013
# Epoch 91/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.4717e-04 - val_loss: 0.0013
# Epoch 92/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.4589e-04 - val_loss: 0.0013
# Epoch 93/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.4465e-04 - val_loss: 0.0013
# Epoch 94/100
# 12/12 [==============================] - 0s 5ms/step - loss: 5.4346e-04 - val_loss: 0.0013
# Epoch 95/100
# 12/12 [==============================] - 0s 6ms/step - loss: 5.4231e-04 - val_loss: 0.0013
# Epoch 96/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.4120e-04 - val_loss: 0.0013
# Epoch 97/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.4013e-04 - val_loss: 0.0013
# Epoch 98/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.3910e-04 - val_loss: 0.0013
# Epoch 99/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.3810e-04 - val_loss: 0.0012
# Epoch 100/100
# 12/12 [==============================] - 0s 4ms/step - loss: 5.3714e-04 - val_loss: 0.0012

# %%
rnn_predict_train = model_rnn.predict(X_train).flatten()
rnn_predict_true = model_rnn.predict(X_val).flatten()
print(f"Val MSE: {history_rnn.history['val_loss'][-1]:.4f}")

plot_predictions(y_train, rnn_predict_train, y_val, rnn_predict_true)
# Out:
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 132ms/step
# Val MSE: 0.0012

# %% [markdown]
# Simple RNN на тестовых данных показывает результат MSE = 0.0014, это может говорить об очень хорошем качестве модели, но проверим качество нейронной сети на кросс-валидации с отрисовыванием графиков.

# %%
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(n_splits=3)

for train_index, test_index in tscv.split(data):
    train_data, test_data = data.iloc[train_index], data.iloc[test_index]

    def create_dataset(dataset, time_steps=1):
        X, y = [], []
        for i in range(len(dataset) - time_steps):
            X.append(dataset.iloc[i:(i + time_steps)])
            y.append(dataset.iloc[i + time_steps])
        return np.array(X), np.array(y)

    # для теста поставим число 3 - четвёртое значение предсказываем на основе 3
    time_steps = 3
    X_train_, y_train_ = create_dataset(train_data, time_steps)
    X_test, y_test = create_dataset(test_data, time_steps)

    X_train_ = np.reshape(X_train_, (X_train_.shape[0], time_steps, 1))
    X_test = np.reshape(X_test, (X_test.shape[0], time_steps, 1))

    early_stop = EarlyStopping(monitor='loss', patience=20)

    model = Sequential([
        SimpleRNN(64, input_shape=(time_steps, 1)),
        Dense(1)
    ])

    model.compile(optimizer='adam', loss='mse')

    history = model.fit(X_train_,
                        y_train_,
                        epochs=100,
                        batch_size=batch_size,
                        verbose=0,
                        callbacks=[early_stop])

    loss = model.evaluate(X_test, y_test, verbose=0)

    predict_train = model.predict(X_train_).flatten()
    predict_true = model.predict(X_test).flatten()
    print(f"Val MSE: {history.history['loss'][-1]:.4f}")

    plot_predictions(y_train_, predict_train, y_test, predict_true)
# Out:
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# Val MSE: 0.0007
# 3/3 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# Val MSE: 0.0013
# 4/4 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# Val MSE: 0.0022

# %% [markdown]
# На кросс-валидации имеем хорошее качество нейронной сети с одним рекуррентным слоем Simple RNN, но такое хорошее качество связано, скорее всего, с тем, что у нас слишком простая структура данных с отчётливым растущим вверх трендом и явной сезонностью на графике.

# %% [markdown]
# ## 2. LSTM

# %%
model_lstm = tf.keras.Sequential([
    tf.keras.layers.LSTM(64,
                         input_shape=(input.shape[1], input.shape[2])),
    tf.keras.layers.Dense(1)])

model_lstm.summary()
# Out:
# Model: "sequential_53"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 64)                16896
#
#  dense_53 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 16961 (66.25 KB)
# Trainable params: 16961 (66.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='loss', patience=10)

model_lstm.compile(optimizer='adam', loss='mse')

history_lstm = model_lstm.fit(train_dataset,
                              epochs=100,
                              batch_size=batch_size,
                              verbose=1,
                              validation_data=val_dataset,
                              callbacks=[early_stop])

# Визуализация процесса обучения
plt.plot(history_lstm.history['loss'], label='LSTM Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 12/12 [==============================] - 2s 46ms/step - loss: 0.0549 - val_loss: 0.0510
# Epoch 2/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0119 - val_loss: 0.0293
# Epoch 3/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0079 - val_loss: 0.0414
# Epoch 4/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0076 - val_loss: 0.0240
# Epoch 5/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0255
# Epoch 6/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0231
# Epoch 7/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0226
# Epoch 8/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0059 - val_loss: 0.0220
# Epoch 9/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0215
# Epoch 10/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0057 - val_loss: 0.0210
# Epoch 11/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0205
# Epoch 12/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0201
# Epoch 13/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0197
# Epoch 14/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0193
# Epoch 15/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0189
# Epoch 16/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0186
# Epoch 17/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0182
# Epoch 18/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0179
# Epoch 19/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0175
# Epoch 20/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0172
# Epoch 21/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0169
# Epoch 22/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0166
# Epoch 23/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0163
# Epoch 24/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0160
# Epoch 25/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0158
# Epoch 26/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0043 - val_loss: 0.0155
# Epoch 27/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0152
# Epoch 28/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0150
# Epoch 29/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.0147
# Epoch 30/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0145
# Epoch 31/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0143
# Epoch 32/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0037 - val_loss: 0.0141
# Epoch 33/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0141
# Epoch 34/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 0.0144
# Epoch 35/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0150
# Epoch 36/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 0.0161
# Epoch 37/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0177
# Epoch 38/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0196
# Epoch 39/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0216
# Epoch 40/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 0.0235
# Epoch 41/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0250
# Epoch 42/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0263
# Epoch 43/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0275
# Epoch 44/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0284
# Epoch 45/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0023 - val_loss: 0.0292
# Epoch 46/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 0.0298
# Epoch 47/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0302
# Epoch 48/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0304
# Epoch 49/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0020 - val_loss: 0.0305
# Epoch 50/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0304
# Epoch 51/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0303
# Epoch 52/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0302
# Epoch 53/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0301
# Epoch 54/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0299
# Epoch 55/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0298
# Epoch 56/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0297
# Epoch 57/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0296
# Epoch 58/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0295
# Epoch 59/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.0295
# Epoch 60/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 0.0294
# Epoch 61/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0294
# Epoch 62/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.0294
# Epoch 63/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0294
# Epoch 64/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0295
# Epoch 65/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.0295
# Epoch 66/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0295
# Epoch 67/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 0.0294
# Epoch 68/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 0.0293
# Epoch 69/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 0.0290
# Epoch 70/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.0286
# Epoch 71/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0280
# Epoch 72/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0271

# %%
lstm_predict_train = model_lstm.predict(X_train).flatten()
lstm_predict_true = model_lstm.predict(X_val).flatten()
print(f"Val MSE: {history_lstm.history['val_loss'][-1]:.4f}")

plot_predictions(y_train, lstm_predict_train, y_val, lstm_predict_true)
# Out:
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 398ms/step
# Val MSE: 0.0271

# %% [markdown]
# Реккурентная сеть с одним слоем LSTM показывает результат значительно хуже, чем сеть с одним слоем Simple RNN. По графику предсказаний видно, что нейронная сеть хуже улавливает волатильность. Возможно, сеть со слоём Simple RNN каким-то образом слишком подстраивается под обучающие данные, и на данных, которые нейронная сеть не видела, LSTM покажет результат лучше.

# %% [markdown]
# ## 3. GRU

# %% [markdown]
# Обучим теперь рекуррентную нейросеть со слоём GRU, сравним с остальными.

# %%
model_gru = tf.keras.Sequential([
    tf.keras.layers.GRU(64,
                        input_shape=(input.shape[1], input.shape[2])),
    tf.keras.layers.Dense(1)])

model_gru.summary()
# Out:
# Model: "sequential_54"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_5 (GRU)                 (None, 64)                12864
#
#  dense_54 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 12929 (50.50 KB)
# Trainable params: 12929 (50.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='loss', patience=10)

model_gru.compile(optimizer='adam', loss='mse')

history_gru = model_gru.fit(train_dataset,
                              epochs=100,
                              batch_size=batch_size,
                              verbose=1,
                              validation_data=val_dataset,
                              callbacks=[early_stop])

# Визуализация процесса обучения
plt.plot(history_gru.history['loss'], label='LSTM Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 12/12 [==============================] - 3s 45ms/step - loss: 0.0231 - val_loss: 0.0202
# Epoch 2/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0088 - val_loss: 0.0425
# Epoch 3/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0073 - val_loss: 0.0300
# Epoch 4/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0061 - val_loss: 0.0228
# Epoch 5/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0236
# Epoch 6/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0206
# Epoch 7/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0204
# Epoch 8/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0195
# Epoch 9/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0191
# Epoch 10/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0048 - val_loss: 0.0185
# Epoch 11/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0181
# Epoch 12/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0176
# Epoch 13/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0171
# Epoch 14/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0044 - val_loss: 0.0167
# Epoch 15/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.0162
# Epoch 16/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0042 - val_loss: 0.0158
# Epoch 17/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0041 - val_loss: 0.0154
# Epoch 18/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.0150
# Epoch 19/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0040 - val_loss: 0.0146
# Epoch 20/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0039 - val_loss: 0.0142
# Epoch 21/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 0.0139
# Epoch 22/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0037 - val_loss: 0.0135
# Epoch 23/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0036 - val_loss: 0.0131
# Epoch 24/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 0.0127
# Epoch 25/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0034 - val_loss: 0.0124
# Epoch 26/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 0.0120
# Epoch 27/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 0.0117
# Epoch 28/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0031 - val_loss: 0.0114
# Epoch 29/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0112
# Epoch 30/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0029 - val_loss: 0.0111
# Epoch 31/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0110
# Epoch 32/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 0.0112
# Epoch 33/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.0115
# Epoch 34/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 0.0120
# Epoch 35/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 0.0125
# Epoch 36/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0130
# Epoch 37/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 0.0132
# Epoch 38/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0130
# Epoch 39/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0127
# Epoch 40/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0123
# Epoch 41/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0119
# Epoch 42/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0117
# Epoch 43/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 0.0115
# Epoch 44/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 0.0112
# Epoch 45/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 0.0109
# Epoch 46/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0106
# Epoch 47/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0103
# Epoch 48/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0100
# Epoch 49/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 50/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 51/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 52/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.0090
# Epoch 53/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0020 - val_loss: 0.0087
# Epoch 54/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0085
# Epoch 55/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0083
# Epoch 56/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0081
# Epoch 57/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0079
# Epoch 58/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0078
# Epoch 59/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0076
# Epoch 60/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0075
# Epoch 61/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0073
# Epoch 62/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0072
# Epoch 63/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0071
# Epoch 64/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0070
# Epoch 65/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0069
# Epoch 66/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0069
# Epoch 67/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0068
# Epoch 68/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 69/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 70/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 71/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.0066
# Epoch 72/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 0.0066
# Epoch 73/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0066
# Epoch 74/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 75/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 76/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 77/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 78/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 79/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 80/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 81/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 82/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 83/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 84/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 85/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0065
# Epoch 86/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0066
# Epoch 87/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0066
# Epoch 88/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.0066
# Epoch 89/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0066
# Epoch 90/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0066
# Epoch 91/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0066
# Epoch 92/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0066
# Epoch 93/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0066
# Epoch 94/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0066
# Epoch 95/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0066
# Epoch 96/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.0067
# Epoch 97/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0067
# Epoch 98/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0067
# Epoch 99/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0067
# Epoch 100/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0067

# %%
gru_predict_train = model_gru.predict(X_train).flatten()
gru_predict_true = model_gru.predict(X_val).flatten()
print(f"Val MSE: {history_gru.history['val_loss'][-1]:.4f}")

plot_predictions(y_train, gru_predict_train, y_val, gru_predict_true)
# Out:
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 371ms/step
# Val MSE: 0.0067

# %% [markdown]
# GRU-слой так же показал высокое качество - выше, чем сеть со слоём LSTM, но несколько хуже, чем Simple RNN.

# %% [markdown]
# ## 4. Simple RNN + LSTM + GRU

# %% [markdown]
# Попробуем построить нейронную сеть со всеми рекуррентными слоями и посмотрим, что получится.

# %%
model_all = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(64, input_shape=(input.shape[1], input.shape[2]), return_sequences=True),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.GRU(64),
    tf.keras.layers.Dense(1)])

model_all.summary()
# Out:
# Model: "sequential_55"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_48 (SimpleRNN)   (None, 12, 64)            4224
#
#  lstm_7 (LSTM)               (None, 12, 64)            33024
#
#  gru_6 (GRU)                 (None, 64)                24960
#
#  dense_55 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 62273 (243.25 KB)
# Trainable params: 62273 (243.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='loss', patience=10)

model_all.compile(optimizer='adam', loss='mse')

history_all = model_all.fit(train_dataset,
                              epochs=100,
                              batch_size=batch_size,
                              verbose=1,
                              validation_data=val_dataset,
                              callbacks=[early_stop])

# Визуализация процесса обучения
plt.plot(history_all.history['loss'], label='All layers Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 12/12 [==============================] - 6s 95ms/step - loss: 0.0196 - val_loss: 0.0397
# Epoch 2/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0376
# Epoch 3/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0326
# Epoch 4/100
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0036 - val_loss: 0.0392
# Epoch 5/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0027 - val_loss: 0.0424
# Epoch 6/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0022 - val_loss: 0.0251
# Epoch 7/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0018 - val_loss: 0.0239
# Epoch 8/100
# 12/12 [==============================] - 0s 19ms/step - loss: 0.0016 - val_loss: 0.0241
# Epoch 9/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0016 - val_loss: 0.0200
# Epoch 10/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0189
# Epoch 11/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0178
# Epoch 12/100
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 0.0160
# Epoch 13/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0147
# Epoch 14/100
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0012 - val_loss: 0.0134
# Epoch 15/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0011 - val_loss: 0.0121
# Epoch 16/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0011 - val_loss: 0.0109
# Epoch 17/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0010 - val_loss: 0.0097
# Epoch 18/100
# 12/12 [==============================] - 0s 15ms/step - loss: 9.6117e-04 - val_loss: 0.0087
# Epoch 19/100
# 12/12 [==============================] - 0s 17ms/step - loss: 9.1178e-04 - val_loss: 0.0077
# Epoch 20/100
# 12/12 [==============================] - 0s 16ms/step - loss: 8.7193e-04 - val_loss: 0.0069
# Epoch 21/100
# 12/12 [==============================] - 0s 17ms/step - loss: 8.4213e-04 - val_loss: 0.0063
# Epoch 22/100
# 12/12 [==============================] - 0s 17ms/step - loss: 8.2131e-04 - val_loss: 0.0058
# Epoch 23/100
# 12/12 [==============================] - 0s 17ms/step - loss: 8.0689e-04 - val_loss: 0.0055
# Epoch 24/100
# 12/12 [==============================] - 0s 17ms/step - loss: 7.9657e-04 - val_loss: 0.0052
# Epoch 25/100
# 12/12 [==============================] - 0s 17ms/step - loss: 7.8868e-04 - val_loss: 0.0050
# Epoch 26/100
# 12/12 [==============================] - 0s 18ms/step - loss: 6.1601e-04 - val_loss: 0.0032
# Epoch 83/100
# 12/12 [==============================] - 0s 18ms/step - loss: 6.1169e-04 - val_loss: 0.0032
# Epoch 84/100
# 12/12 [==============================] - 0s 18ms/step - loss: 6.0736e-04 - val_loss: 0.0032
# Epoch 85/100
# 12/12 [==============================] - 0s 18ms/step - loss: 6.0302e-04 - val_loss: 0.0031
# Epoch 86/100
# 12/12 [==============================] - 0s 17ms/step - loss: 5.9872e-04 - val_loss: 0.0031
# Epoch 87/100
# 12/12 [==============================] - 0s 18ms/step - loss: 5.9446e-04 - val_loss: 0.0031
# Epoch 88/100
# 12/12 [==============================] - 0s 16ms/step - loss: 5.9032e-04 - val_loss: 0.0030
# Epoch 89/100
# 12/12 [==============================] - 0s 17ms/step - loss: 5.8628e-04 - val_loss: 0.0030
# Epoch 90/100
# 12/12 [==============================] - 0s 18ms/step - loss: 5.8242e-04 - val_loss: 0.0030
# Epoch 91/100
# 12/12 [==============================] - 0s 19ms/step - loss: 5.7869e-04 - val_loss: 0.0030
# Epoch 92/100
# 12/12 [==============================] - 0s 16ms/step - loss: 5.7519e-04 - val_loss: 0.0029
# Epoch 93/100
# 12/12 [==============================] - 0s 17ms/step - loss: 5.7183e-04 - val_loss: 0.0029
# Epoch 94/100
# 12/12 [==============================] - 0s 18ms/step - loss: 5.6871e-04 - val_loss: 0.0029
# Epoch 95/100
# 12/12 [==============================] - 0s 18ms/step - loss: 5.6569e-04 - val_loss: 0.0029
# Epoch 96/100
# 12/12 [==============================] - 0s 17ms/step - loss: 5.6292e-04 - val_loss: 0.0029
# Epoch 97/100
# 12/12 [==============================] - 0s 17ms/step - loss: 5.6019e-04 - val_loss: 0.0028
# Epoch 98/100
# 12/12 [==============================] - 0s 17ms/step - loss: 5.5770e-04 - val_loss: 0.0028
# Epoch 99/100
# 12/12 [==============================] - 0s 19ms/step - loss: 5.5516e-04 - val_loss: 0.0028
# Epoch 100/100
# 12/12 [==============================] - 0s 17ms/step - loss: 5.5288e-04 - val_loss: 0.0028

# %%
all_predict_train = model_all.predict(X_train).flatten()
all_predict_true = model_all.predict(X_val).flatten()
print(f"Val MSE: {history_all.history['val_loss'][-1]:.4f}")

plot_predictions(y_train, all_predict_train, y_val, all_predict_true)
# Out:
# 3/3 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 1s 856ms/step
# Val MSE: 0.0028

# %% [markdown]
# # Выводы

# %% [markdown]
# Имеем следующие результаты:
# * Simple RNN показала качество MSE = 0.0012;
# * LSTM показала MSE = 0.0128;
# * GRU показала MSE = 0.0063;
# * Simple RNN + LSTM + GRU показала MSE = 0.0136.

# %% [markdown]
# * Лучше всех отработала самая простая нейронная сеть с одним слоем Simple RNN;
# * Хуже всех на тестовых данных отработал слой LSTM;
# * Очень высокое качество на тестовых данных может говорить о том, что наши данные имеют слишком простую и очевидную структуру, что даже самая простая нейросеть имеет очень высокое качество;
# * Возможно, ради эксприментов стоит убрать станционарность ряда (логарифмирование, сезонная дифференциация и так далее) и построить ARIMA-модель или же использовать градиентные бустинги.
